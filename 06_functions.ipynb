# %% [markdown]
# <a href="https://colab.research.google.com/github/AsnaSiddiqui/GIAIC-Python-Assignment-4/blob/main/06_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_averages \n")


def calculate_average(numbers):
    if not numbers:
        return 0
    return sum(numbers) / len(numbers)

def main():
    print("Enter numbers separated by commas:")
    user_input = input("→ ")


    try:
        number_list = [float(num.strip()) for num in user_input.split(",")]
    except ValueError:
        print(" Invalid input! Please enter valid numbers")
        return

    avg = calculate_average(number_list)
    print(f"Average of the given numbers: {avg:.2f}")

if __name__ == "__main__":
    main()
# Out:
# 00_averages
#
# Enter numbers separated by commas:
# → 54,99
# Average of the given numbers: 76.50

# %%
import random
import time

print("01_chaotic_countin \n")


def chaotic_counting(start, end, delay=0.5):
    numbers = list(range(start, end + 1))
    random.shuffle(numbers)

    print("Chaotic Counting Begins!")
    for number in numbers:
        print(number)
        time.sleep(delay)
    print("Done with chaotic counting!")

def main():
    print("Enter start and end numbers for chaotic counting.")
    try:
        start = int(input("Start → "))
        end = int(input("End → "))

        if start > end:
            print(" Start should be less than or equal to end!")
            return

        chaotic_counting(start, end)
    except ValueError:
        print(" Invalid input! Please enter integers only.")

if __name__ == "__main__":
    main()
# Out:
# 01_chaotic_countin
#
# Enter start and end numbers for chaotic counting.
# Start → 6
# End → 20
# Chaotic Counting Begins!
# 19
# 6
# 17
# 11
# 7
# 9
# 16
# 20
# 8
# 10
# 18
# 15
# 14
# 13
# 12
# Done with chaotic counting!

# %%
print("02_count_even \n")


def count_even_numbers(numbers):
    even_numbers = [num for num in numbers if num % 2 == 0]
    return len(even_numbers), even_numbers

def main():
    print("Enter numbers separated by commas:")
    user_input = input("→ ")

    try:
        number_list = [int(num.strip()) for num in user_input.split(",")]
    except ValueError:
        print("Invalid input! Please enter integers only.")
        return

    count, evens = count_even_numbers(number_list)
    print(f"Total even numbers: {count}")
    print(f"Even numbers: {evens}")

if __name__ == "__main__":
    main()
# Out:
# 02_count_even
#
# Enter numbers separated by commas:
# → 33,44
# Total even numbers: 1
# Even numbers: [44]

# %%
print("04_double \n")

def double_numbers(numbers):
    return [num * 2 for num in numbers]

def main():
    print("Enter numbers separated by commas to double them:")
    user_input = input("→ ")

    try:
        number_list = [int(num.strip()) for num in user_input.split(",")]
    except ValueError:
        print("Invalid input! Please enter integers only.")
        return

    doubled = double_numbers(number_list)
    print(f"Doubled numbers: {doubled}")

if __name__ == "__main__":
    main()
# Out:
# 04_double
#
# Enter numbers separated by commas to double them:
# → 2,4
# Doubled numbers: [4, 8]

# %%
print("05_get_name \n")

def get_name():
    name = input("What's your name? → ").strip()

    if not name:
        print("You didn't enter a name!")
    else:
        print(f"Hello, {name}! Nice to talk to you!")

def main():
    get_name()

if __name__ == "__main__":
    main()
# Out:
# 05_get_name
#
# What's your name? → Asna
# Hello, Asna! Nice to talk to you!

# %%
print("06_is_odd \n")

def is_odd(number):
    return number % 2 != 0

def main():
    try:
        num = int(input("Enter a number to check if it's odd: → "))
    except ValueError:
        print("Invalid input! Please enter a valid integer.")
        return

    if is_odd(num):
        print(f"{num} is an odd number.")
    else:
        print(f"{num} is not an odd number (it's even).")

if __name__ == "__main__":
    main()
# Out:
# 06_is_odd
#
# Enter a number to check if it's odd: → 3
# 3 is an odd number.

# %%
print("07_print_divisor \n")

def print_divisors(n):
    print(f" Divisors of {n} is:")
    for i in range(1, n + 1):
        if n % i == 0:
            print(f"➤ {i}")

def main():
    try:
        num = int(input("Enter a number to find its divisors: → "))
        if num <= 0:
            print("Please enter a positive integer greater than 0.")
            return
    except ValueError:
        print("Invalid input! Please enter a valid number.")
        return

    print_divisors(num)

if __name__ == "__main__":
    main()
# Out:
# 07_print_divisor
#
# Enter a number to find its divisors: → 4
#  Divisors of 4 is:
# ➤ 1
# ➤ 2
# ➤ 4

# %%
print("08_print_multiple \n")

def print_multiples(n, count):
    print(f"First {count} multiples of {n} are:")
    for i in range(1, count + 1):
        print(f"{n} × {i} = {n * i}")

def main():
    try:
        num = int(input("Enter a number to find its multiples: "))
        count = int(input("How many multiples do you want to see?  "))
        if num <= 0 or count <= 0:
            print("Please enter positive numbers only.")
            return
    except ValueError:
        print("Invalid input! Please enter integers only.")
        return

    print_multiples(num, count)

if __name__ == "__main__":
    main()
# Out:
# 08_print_multiple
#
# Enter a number to find its multiples: 2
# How many multiples do you want to see?  5
# First 5 multiples of 2 are:
# 2 × 1 = 2
# 2 × 2 = 4
# 2 × 3 = 6
# 2 × 4 = 8
# 2 × 5 = 10

# %%
import random

print("09_sentence_generator \n")

nouns = ["cat", "boy", "girl", "dog", "robot"]
verbs = ["eats", "plays with", "runs to", "looks at", "builds"]
places = ["the park", "school", "home", "the moon", "a castle"]

def generate_sentence():
    noun = random.choice(nouns)
    verb = random.choice(verbs)
    place = random.choice(places)
    return f"The {noun} {verb} {place}."

def main():
    try:
        count = int(input("How many sentences do you want to generate? "))
        if count <= 0:
            print("Please enter a positive number.")
            return
    except ValueError:
        print(" Invalid input! Please enter a valid number.")
        return

    print("\n Generated Sentences:")
    for _ in range(count):
        print("➤", generate_sentence())

if __name__ == "__main__":
    main()
# Out:
# 09_sentence_generator
#
# How many sentences do you want to generate? 5
#
#  Generated Sentences:
# ➤ The robot plays with the moon.
# ➤ The girl runs to a castle.
# ➤ The cat looks at the moon.
# ➤ The robot looks at home.
# ➤ The cat looks at the moon.

# %%
print("10_print_ones_digit \n")

def get_ones_digit(number):
    return abs(number) % 10

def main():
    try:
        num = int(input("Enter a number:  "))
    except ValueError:
        print("Please enter a valid integer.")
        return

    ones_digit = get_ones_digit(num)
    print(f"The ones digit of {num} is: {ones_digit}")

if __name__ == "__main__":
    main()
# Out:
# 10_print_ones_digit
#
# Enter a number:  345474
# The ones digit of 345474 is: 4
